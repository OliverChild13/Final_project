# %%
import pandas as pd
import plotly.express as px
from itables import show

# %%
file_location = '../Final_project/Main Data/2019.csv'
file_name = '../Final_project/Main Data/iceland_benefits.xlsx'
file_name2 = '../Final_project/Main Data/iceland_income_support.xlsx'
DF_inc = pd.read_excel(file_name2)
DF_ben = pd.read_excel(file_name)
DF = pd.read_csv(file_location)

# %%
DF.sort_values('Social support', ascending=False).tail(10)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 146           147                     Haiti  3.597           0.323
# 118           119                   Georgia  4.519           0.886
# 155           156               South Sudan  2.853           0.306
# 138           139                      Togo  4.085           0.275
# 149           150                    Malawi  3.410           0.191
# 153           154               Afghanistan  3.203           0.350
# 144           145                   Burundi  3.775           0.046
# 101           102                     Benin  4.883           0.393
# 148           149                     Syria  3.462           0.619
# 154           155  Central African Republic  3.083           0.026
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 146           0.688                    0.449                         0.026
# 118           0.666                    0.752                         0.346
# 155           0.575                    0.295                         0.010
# 138           0.572                    0.410                         0.293
# 149           0.560                    0.495                         0.443
# 153           0.517                    0.361                         0.000
# 144           0.447                    0.380                         0.220
# 101           0.437                    0.397                         0.349
# 148           0.378                    0.440                         0.013
# 154           0.000                    0.105                         0.225
#
#      Generosity  Perceptions of corruption
# 146       0.419                      0.110
# 118       0.043                      0.164
# 155       0.202                      0.091
# 138       0.177                      0.085
# 149       0.218                      0.089
# 153       0.158                      0.025
# 144       0.176                      0.180
# 101       0.175                      0.082
# 148       0.331                      0.141
# 154       0.235                      0.035

# %%
DF_ben = DF_ben.dropna()
DF_ben
# Out:
#   Funding of social security pension schemes and social assistance benefits 1975-2016    \
# 3                            Social security pension
# 4                         Social assistance benefits
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3      2016.0      84140      59332      24808        100       70.5
# 4      2016.0      15411          .      15411        100          .
#
#   Unnamed: 7
# 3       29.5
# 4        100

# %%
DF_inc.dropna()
DF_inc
# Out:
#    Recipients of municipal income support and average payments 1997-2022  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                2019
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                              Unit:
# 15                             Thereof new recipient:
# 16                      Fengu ekki greitt á fyrra ári
# 17                                                NaN
# 18                                                NaN
# 19                                     Latest update:
# 20                                     20230628 09:00
# 21                                                NaN
# 22                                            Source:
# 23                                 Statistics Iceland
# 24                                                NaN
# 25                                                NaN
# 26                                          Copyright
# 27                                                NaN
# 28                                             Units:
# 29                                         Number/ISK
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                           Internal reference code:
# 40                                           HEI09101
#
#                Unnamed: 1       Unnamed: 2             Unnamed: 3  \
# 0                     NaN              NaN                    NaN
# 1                     NaN  Number of homes  Thereof new recipient
# 2                   Total             5660                   2722
# 3          Capital region             4177                   2131
# 4               Reykjavík             3043                   1667
# 5   Capital region, other             1134                    464
# 6               Southwest              383                    139
# 7                    West              136                     53
# 8              Westfjords               84                     37
# 9               Northwest               63                     26
# 10              Northeast              438                    195
# 11                   East              111                     47
# 12                  South              268                     94
# 13                    NaN              NaN                    NaN
# 14                    NaN              NaN                    NaN
# 15                    NaN              NaN                    NaN
# 16                    NaN              NaN                    NaN
# 17                    NaN              NaN                    NaN
# 18                    NaN              NaN                    NaN
# 19                    NaN              NaN                    NaN
# 20                    NaN              NaN                    NaN
# 21                    NaN              NaN                    NaN
# 22                    NaN              NaN                    NaN
# 23                    NaN              NaN                    NaN
# 24                    NaN              NaN                    NaN
# 25                    NaN              NaN                    NaN
# 26                    NaN              NaN                    NaN
# 27                    NaN              NaN                    NaN
# 28                    NaN              NaN                    NaN
# 29                    NaN              NaN                    NaN
# 30                    NaN              NaN                    NaN
# 31                    NaN              NaN                    NaN
# 32                    NaN              NaN                    NaN
# 33                    NaN              NaN                    NaN
# 34                    NaN              NaN                    NaN
# 35                    NaN              NaN                    NaN
# 36                    NaN              NaN                    NaN
# 37                    NaN              NaN                    NaN
# 38                    NaN              NaN                    NaN
# 39                    NaN              NaN                    NaN
# 40                    NaN              NaN                    NaN
#
#                                   Unnamed: 4  \
# 0                                        NaN
# 1   Income support expenditure, thousand ISK
# 2                                    4154434
# 3                                    3437099
# 4                                    2739922
# 5                                     697177
# 6                                     220568
# 7                                      53032
# 8                                      30483
# 9                                      41953
# 10                                    203249
# 11                                     48426
# 12                                    119624
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# 30                                       NaN
# 31                                       NaN
# 32                                       NaN
# 33                                       NaN
# 34                                       NaN
# 35                                       NaN
# 36                                       NaN
# 37                                       NaN
# 38                                       NaN
# 39                                       NaN
# 40                                       NaN
#
#                                       Unnamed: 5  \
# 0                                            NaN
# 1   Average monthly income support per home, ISK
# 2                                         160800
# 3                                         170677
# 4                                         178010
# 5                                         146898
# 6                                         136659
# 7                                          98756
# 8                                         105115
# 9                                         149832
# 10                                        137516
# 11                                        106198
# 12                                        114692
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                                           NaN
# 30                                           NaN
# 31                                           NaN
# 32                                           NaN
# 33                                           NaN
# 34                                           NaN
# 35                                           NaN
# 36                                           NaN
# 37                                           NaN
# 38                                           NaN
# 39                                           NaN
# 40                                           NaN
#
#                        Unnamed: 6
# 0                             NaN
# 1   Average number of months paid
# 2                             4.6
# 3                             4.8
# 4                             5.1
# 5                             4.2
# 6                             4.2
# 7                             3.9
# 8                             3.5
# 9                             4.4
# 10                            3.4
# 11                            4.1
# 12                            3.9
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
# 18                            NaN
# 19                            NaN
# 20                            NaN
# 21                            NaN
# 22                            NaN
# 23                            NaN
# 24                            NaN
# 25                            NaN
# 26                            NaN
# 27                            NaN
# 28                            NaN
# 29                            NaN
# 30                            NaN
# 31                            NaN
# 32                            NaN
# 33                            NaN
# 34                            NaN
# 35                            NaN
# 36                            NaN
# 37                            NaN
# 38                            NaN
# 39                            NaN
# 40                            NaN
